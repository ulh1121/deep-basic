# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# X and Y data
x_train=[1,2,3]
y_train=[1,2,3]

W=tf.Variable(tf.random_normal([1]), name='weight')
b=tf.Variable(tf.random_normal([1]), name='bias')

#Our hypothesis XW+b
hypothesis=x_train*W + b

# %%
cost=tf.reduce_mean(tf.square(hypothesis-y_train))

# %%
#Minimize
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
train=optimizer.minimize(cost)

# %%
#Launch the graph in a session
sess=tf.Session()
#Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# %%
#Gir the Line
for step in range(2001):
    sess.run(train)
    if step%20==0 :
        print(step, sess.run(cost),sess.run(W),sess.run(b))
# Out:
# 0 0.91461086 [0.08376145] [1.2367013]
# 20 0.2517679 [0.3943316] [1.2962592]
# 40 0.22341098 [0.44826803] [1.246545]
# 60 0.20285775 [0.47662285] [1.1890287]
# 80 0.18423821 [0.50145066] [1.1332502]
# 100 0.16732806 [0.52490264] [1.0800012]
# 120 0.15196992 [0.54723275] [1.0292457]
# 140 0.1380215 [0.56851137] [0.98087496]
# 160 0.12535332 [0.5887898] [0.93477744]
# 180 0.113847874 [0.6081152] [0.89084625]
# 200 0.103398435 [0.6265324] [0.8489797]
# 220 0.09390814 [0.6440839] [0.8090808]
# 240 0.08528886 [0.6608107] [0.77105695]
# 260 0.07746073 [0.6767513] [0.7348201]
# 280 0.07035109 [0.69194275] [0.70028645]
# 300 0.063893974 [0.7064204] [0.6673755]
# 320 0.058029532 [0.7202175] [0.63601136]
# 340 0.05270334 [0.7333663] [0.6061211]
# 360 0.047866017 [0.7458971] [0.57763565]
# 380 0.043472677 [0.7578391] [0.5504887]
# 400 0.03948258 [0.76921976] [0.52461773]
# 420 0.035858717 [0.78006554] [0.49996278]
# 440 0.032567468 [0.79040164] [0.4764664]
# 460 0.029578293 [0.80025196] [0.45407423]
# 480 0.02686348 [0.8096394] [0.43273437]
# 500 0.024397837 [0.81858563] [0.41239744]
# 520 0.022158518 [0.8271114] [0.39301634]
# 540 0.020124728 [0.8352365] [0.37454605]
# 560 0.018277606 [0.8429798] [0.3569438]
# 580 0.016600013 [0.85035914] [0.34016877]
# 600 0.015076394 [0.85739166] [0.32418212]
# 620 0.013692637 [0.8640937] [0.30894685]
# 640 0.012435865 [0.87048084] [0.29442748]
# 660 0.011294465 [0.8765677] [0.2805905]
# 680 0.010257803 [0.8823686] [0.26740378]
# 700 0.009316307 [0.8878968] [0.2548368]
# 720 0.008461222 [0.8931653] [0.24286044]
# 740 0.0076846164 [0.898186] [0.23144692]
# 760 0.0069792974 [0.90297097] [0.2205698]
# 780 0.006338703 [0.9075309] [0.21020384]
# 800 0.0057569146 [0.9118767] [0.20032501]
# 820 0.0052285227 [0.9160182] [0.19091044]
# 840 0.0047486243 [0.919965] [0.18193834]
# 860 0.004312776 [0.9237264] [0.17338794]
# 880 0.003916934 [0.92731094] [0.16523933]
# 900 0.0035574168 [0.9307271] [0.15747368]
# 920 0.0032309068 [0.9339826] [0.15007296]
# 940 0.0029343597 [0.9370852] [0.14302011]
# 960 0.0026650364 [0.94004196] [0.1362987]
# 980 0.0024204236 [0.94285977] [0.12989315]
# 1000 0.0021982696 [0.9455452] [0.12378865]
# 1020 0.001996505 [0.9481043] [0.11797101]
# 1040 0.0018132589 [0.9505433] [0.11242681]
# 1060 0.0016468259 [0.95286757] [0.10714313]
# 1080 0.0014956761 [0.9550826] [0.10210779]
# 1100 0.0013583949 [0.9571936] [0.09730908]
# 1120 0.0012337166 [0.9592052] [0.09273593]
# 1140 0.001120479 [0.9611226] [0.08837765]
# 1160 0.0010176403 [0.96294963] [0.08422422]
# 1180 0.0009242364 [0.96469086] [0.080266]
# 1200 0.0008394061 [0.96635026] [0.07649378]
# 1220 0.00076236203 [0.9679317] [0.07289886]
# 1240 0.0006923885 [0.9694388] [0.06947288]
# 1260 0.0006288361 [0.9708751] [0.06620783]
# 1280 0.0005711187 [0.97224385] [0.06309629]
# 1300 0.0005187014 [0.9735483] [0.060131]
# 1320 0.0004710917 [0.97479147] [0.05730505]
# 1340 0.00042785276 [0.97597617] [0.05461189]
# 1360 0.00038858014 [0.97710526] [0.05204531]
# 1380 0.00035291622 [0.9781811] [0.04959935]
# 1400 0.00032052325 [0.9792066] [0.04726838]
# 1420 0.0002911033 [0.9801839] [0.04504687]
# 1440 0.0002643851 [0.9811151] [0.04292979]
# 1460 0.00024011896 [0.9820027] [0.04091223]
# 1480 0.0002180796 [0.9828484] [0.0389895]
# 1500 0.0001980634 [0.9836545] [0.03715715]
# 1520 0.00017988523 [0.9844226] [0.03541093]
# 1540 0.00016337424 [0.9851547] [0.03374679]
# 1560 0.00014837884 [0.98585236] [0.03216083]
# 1580 0.00013476038 [0.98651725] [0.03064939]
# 1600 0.00012239201 [0.9871509] [0.02920901]
# 1620 0.00011115868 [0.98775476] [0.02783628]
# 1640 0.00010095655 [0.98833025] [0.0265281]
# 1660 9.1690286e-05 [0.98887867] [0.02528141]
# 1680 8.3274375e-05 [0.98940134] [0.02409329]
# 1700 7.5631295e-05 [0.9898993] [0.02296106]
# 1720 6.868879e-05 [0.9903742] [0.02188194]
# 1740 6.238491e-05 [0.99082655] [0.02085353]
# 1760 5.6659002e-05 [0.9912576] [0.01987347]
# 1780 5.1457944e-05 [0.9916685] [0.01893947]
# 1800 4.6735597e-05 [0.99206007] [0.01804938]
# 1820 4.244524e-05 [0.9924332] [0.01720113]
# 1840 3.8549857e-05 [0.9927888] [0.01639274]
# 1860 3.5012024e-05 [0.9931277] [0.01562235]
# 1880 3.1797837e-05 [0.9934507] [0.01488815]
# 1900 2.8879253e-05 [0.9937585] [0.01418845]
# 1920 2.6228721e-05 [0.99405175] [0.01352165]
# 1940 2.3821718e-05 [0.9943313] [0.0128862]
# 1960 2.1634942e-05 [0.99459773] [0.0122806]
# 1980 1.9649171e-05 [0.99485165] [0.01170346]
# 2000 1.7845503e-05 [0.99509364] [0.01115339]
